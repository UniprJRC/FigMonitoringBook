% %% [markdown]
% # <span style="color:rgb(213,80,0)">Exercise 8.2</span>
%
% Differences and similarities between HAR and ART heteroskedasticity. This file creates Figures 8.45-8.46.
%
% ## Beginning of code

% %%
load inttrade1.mat
% This dataset refers to 'POD_4801000000_CH_IT
X=inttrade1.Weight;
y=inttrade1.Value;
prin=0;
close all
X=X./max(X);
Z=log(X);
n=length(y);
% In this Exercise Harvery's heteroskedasiticty is used
typeH='har';

% %% [markdown]
% ## Create Figure A.45
%
% Automatic outlier detection

% %%
bonflev=0.99;
outH=FSRH(y,X,Z,'init',round(n*0.8),'plots',1,'ylim',[1.6 3], ...
    'typeH',typeH,'bonflev',bonflev,'nsamp',10000);
% Out:
% Total estimated time to complete LMS:  1.14 seconds
% -------------------------
% Signal detection loop
% mdr(3826,3867)>99% Bonferroni level
% ----------------------------
% Final output
% Number of units declared as outliers=41

% %%
pl_fsr=findobj(0, 'type', 'figure','tag','pl_fsr');
close(figure(pl_fsr(end)))

pl_fsr=findobj(0, 'type', 'figure','tag','pl_yX');
set(gcf,'Name', 'Figure A.45');
title('Figure A.45')
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_0.png"></center>

% %%
outl=outH.ListOut;
bsb=1:n;
bsb(outl)=[];

% %% [markdown]
% ## Prepare input for Figure 8.46

% %%
[outLXS]=LXS(y,X,'nsamp',1000);
% Out:
% Total estimated time to complete LMS:  0.09 seconds

% %%
outHEDA=FSRHeda(y,X,Z,outLXS.bs,'init',round(0.7*length(y)),'typeH',typeH);
% Out:
% m=100
% m=200
% m=300
% m=400
% m=500
% m=600
% m=700
% m=800
% m=900
% m=1000
% m=1100
% m=1200
% m=1300
% m=1400
% m=1500
% m=1600
% m=1700
% m=1800
% m=1900
% m=2000
% m=2100
% m=2200
% m=2300
% m=2400
% m=2500
% m=2600
% m=2700
% m=2800
% m=2900
% m=3000
% m=3100
% m=3200
% m=3300
% m=3400
% Warning: interchange greater than 10 when m=3477
% Warning: interchange greater than 10 when m=3478
% m=3500
% m=3600
% m=3700
% m=3800

% %% [markdown]
% ## Create Figure A.46
%
% Forecasts with confidence bands

% %%
figure
forecastH(y,X,Z,'outH',outHEDA,'bsb',bsb,'conflev',1-0.01/n);
% scatter(X,y)
title('')
ylabel(typeH)
ylabel('Value')
xlabel('Weight')
if prin==1
    print -depsc P48bandsHhar.eps;
end

set(gcf,'Name', 'Figure A.46');
title('Figure A.46')
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_1.png"></center>

% %%
%InsideREADME
