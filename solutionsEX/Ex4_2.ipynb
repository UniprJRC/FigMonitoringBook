% %% [markdown]
% # <span style="color:rgb(213,80,0)">Exercise 4.2</span>
%
% Hawkins data: brushing residuals from monitoring S residuals This file creates Figures A.7--A.9
%
% ## Hawkins data:
%
% brushing residuals from monitoring S residuals

% %%
close all;
load('hawkins.txt');
y=hawkins(:,9);
X=hawkins(:,1:8);

n=length(y);
prin=0;

% %% [markdown]
% ## Prepare the input for Figures A.7, A.8 and A.9
%
% Sregeda with bisquare link brushing

% %%
% Perform both the FS and the S residuals monitoring
[outLXS]=LXS(y,X,'nsamp',10000);
% Out:
% Total estimated time to complete LMS:  0.07 seconds

% %%
[outFS]=FSReda(y,X,outLXS.bs);

outTB=Sregeda(y,X,'plots',1,'rhofunc','bisquare');
% Out:
% Total estimated time to complete S estimate:  4.21 seconds
% Total estimated time to complete S estimate:  3.39 seconds
% Total estimated time to complete S estimate:  1.49 seconds
% Total estimated time to complete S estimate:  1.92 seconds
% Total estimated time to complete S estimate:  1.47 seconds
% Total estimated time to complete S estimate:  2.47 seconds
% Total estimated time to complete S estimate:  1.47 seconds
% Total estimated time to complete S estimate:  1.43 seconds
% Total estimated time to complete S estimate:  1.40 seconds
% Total estimated time to complete S estimate:  1.38 seconds
% Total estimated time to complete S estimate:  1.63 seconds
% Total estimated time to complete S estimate:  1.37 seconds
% Total estimated time to complete S estimate:  1.43 seconds
% Total estimated time to complete S estimate:  1.27 seconds
% Total estimated time to complete S estimate:  1.39 seconds
% Total estimated time to complete S estimate:  1.24 seconds
% Total estimated time to complete S estimate:  1.18 seconds
% Total estimated time to complete S estimate:  1.13 seconds
% Total estimated time to complete S estimate:  1.10 seconds
% Total estimated time to complete S estimate:  1.10 seconds
% Total estimated time to complete S estimate:  1.15 seconds
% Total estimated time to complete S estimate:  1.27 seconds
% Total estimated time to complete S estimate:  1.08 seconds
% Total estimated time to complete S estimate:  1.09 seconds
% Total estimated time to complete S estimate:  1.09 seconds
% Total estimated time to complete S estimate:  1.12 seconds
% Total estimated time to complete S estimate:  1.11 seconds
% Total estimated time to complete S estimate:  1.93 seconds
% Total estimated time to complete S estimate:  1.15 seconds
% Total estimated time to complete S estimate:  1.08 seconds
% Total estimated time to complete S estimate:  1.10 seconds
% Total estimated time to complete S estimate:  1.13 seconds
% Total estimated time to complete S estimate:  1.06 seconds
% Total estimated time to complete S estimate:  1.01 seconds
% Total estimated time to complete S estimate:  1.34 seconds
% Total estimated time to complete S estimate:  0.89 seconds
% Total estimated time to complete S estimate:  0.89 seconds
% Total estimated time to complete S estimate:  0.95 seconds
% Total estimated time to complete S estimate:  0.86 seconds
% Total estimated time to complete S estimate:  0.83 seconds
% Total estimated time to complete S estimate:  0.84 seconds
% Total estimated time to complete S estimate:  0.78 seconds
% Total estimated time to complete S estimate:  0.73 seconds
% Total estimated time to complete S estimate:  0.76 seconds
% Total estimated time to complete S estimate:  0.77 seconds
% Total estimated time to complete S estimate:  0.76 seconds
% Total estimated time to complete S estimate:  0.70 seconds
% Total estimated time to complete S estimate:  0.89 seconds
% Total estimated time to complete S estimate:  0.70 seconds
% Total estimated time to complete S estimate:  0.70 seconds

% %%
yl=5;
ylim([-yl yl])
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_0.png"></center>

% %%
% The information about the order of entry of the units in the FS is added
% to outTB
outTB.Un=outFS.Un;

% %% [markdown]
% ## Create Figure A.7-A.9
%
% Show the plot of minimum deletion residuals

% %%
mdrplot(outFS,'ylimy',[1 8])
% Out:
% Warning: Upper limit of y axis of the mdr forward plot set to 20
% <center><img src="data:image/png;base64,..." width="562" alt="figure_1.png"></center>
% ans =
%      []

% %%
standard=struct;
standard.ylim=[-yl yl];

databrush=struct;
databrush.bivarfit='';
databrush.selectionmode='Brush'; % Brush selection
% databrush.persist='on'; % Enable repeated mouse selections
databrush.Label='off'; % Write labels of trajectories while selecting
databrush.RemoveLabels='off'; % Do not remove labels after selection

disp('Brush the monitoring residual plot')
% Out:
% Brush the monitoring residual plot

% %%
resfwdplot(outTB,'databrush',databrush,'datatooltip','','standard',standard)
% Out:
% Select a region to brush in the monitoring residual plot

% %%
if prin==1
    % print to postscript
    print -depsc HDtbexeres6.eps;
    print -depsc HDtbexemdr6.eps;

    print -depsc HDtbexeres.eps;
    print -depsc HDtbexemdr.eps;
    print -depsc HDtbexeyXplot.eps;
end

%InsideREADME
