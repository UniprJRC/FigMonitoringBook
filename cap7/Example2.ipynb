% %% [markdown]
% # <span style="color:rgb(213,80,0)">Example 2, 4 explanatory variables (section 7.5.2).</span>
%
% This file creates Figures 7.10\-7.12
%
% ## Beginning of code

% %%
clear
rng(100)
x1 = (0:0.1:15)';
n=length(x1);
X24=randn(n,3);
y = sin(x1) + 0.5*(rand(size(x1))-0.5) + X24*(1:3)';
y([90,100,105:110]) = 1;
X=[x1 X24];
y=exp(y);
prin=0;

% %% [markdown]
% ## Example 2: automatic model selection create figure 7.10

% %%
[VALtfin,~]=avasms(y,X);
% Out:
% No model found with pvalDW>0.1 and pvalJB>0.1
% Setting pvalDW=0.05 and pvalJB=0.05
% <center><img src="data:image/png;base64,..." width="562" alt="figure_0.png"></center>

% %%
disp(VALtfin)
% Out:
%     orderR2    rob    scail    tyinitial    trapezoid      R2       pvalDW      pvalJB     nused                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                res                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Out           ord
%     _______    ___    _____    _________    _________    _______    _______    ________    _____    ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________    ____________    _______
%        1        1       1          1            1        0.99845    0.61042    0.089905     142     {[0.0091 9.7431e-04 -0.0109 0.0095 -0.0396 -0.0236 0.0684 -0.0166 -0.0073 0.0151 0.0756 0.0046 0.0307 0.0517 -0.0403 -0.0373 0.0617 0.0693 0.0369 -0.0222 -0.0436 -0.0381 -0.0256 0.0855 0.0764 -0.0500 0.0493 0.0317 0.0155 0.0699 -0.0481 0.0011 -0.0158 0.0199 -0.0603 0.0089 -0.0198 0.0137 -0.0539 0.0108 0.0017 -0.0497 -0.0178 -0.0402 0.0166 -0.0083 -0.0370 -0.0150 -0.0333 0.0149 -0.0098 -0.0588 0.1022 0.0363 -0.0305 -0.0403 -0.0542 -0.0060 -0.0732 0.0605 0.0527 0.0083 -0.0094 -0.0422 0.0054 -0.0051 0.0621 -0.0263 0.0126 -0.0219 0.0431 0.0035 -0.0333 0.0650 -0.0109 0.0392 0.0293 -1.8256e-05 0.0054 -0.0109 -0.0262 0.0123 0.0511 0.0552 0.0335 0.0030 0.0361 -0.0173 0.0355 1.0633 -0.0557 0.0277 -0.0019 0.0472 0.0609 -0.0320 -0.0631 0.0324 -0.0452 -1.2558 3.1245e-04 -0.0936 -0.0462 -0.0357 -0.2204 -1.8685 -0.2119 1.4524 -1.0562 0.5407 -0.0653 -0.0581 -0.0192 -0.0065 0.0453 -0.0359 -0.0311 -0.0436 -0.0380 -0.0762 0.0244 -0.0195 -0.0316 0.0489 0.0492 -0.0070 -0.0175 0.0352 -0.0532 -0.0100 0.0460 0.0375 0.0379 -0.0684 0.0035 0.0483 0.0478 0.0155 -0.0552 0.0267 0.0064 0.0289 0.0363 0.0036 0.0709 -0.0088 -0.0561 0.0017 0.0464 -0.0245 0.0015]}    {1x1 struct}    0.57314
%        1        1       1          1            0        0.99844     0.3176    0.088198     142     {[0.0090 9.6726e-04 -0.0109 0.0094 -0.0397 -0.0235 0.0685 -0.0165 -0.0074 0.0152 0.0756 0.0047 0.0308 0.0512 -0.0402 -0.0372 0.0619 0.0694 0.0371 -0.0234 -0.0434 -0.0380 -0.0255 0.0857 0.0765 -0.0499 0.0493 0.0317 0.0154 0.0699 -0.0479 0.0011 -0.0158 0.0197 -0.0606 0.0088 -0.0199 0.0135 -0.0526 0.0108 0.0014 -0.0498 -0.0181 -0.0404 0.0166 -0.0083 -0.0371 -0.0150 -0.0331 0.0148 -0.0099 -0.0590 0.0528 0.0364 -0.0305 -0.0402 -0.0542 -0.0061 -0.0733 0.0604 0.0531 0.0083 -0.0093 -0.0422 0.0054 -0.0051 0.0620 -0.0262 0.0126 -0.0222 0.0432 0.0036 -0.0335 0.0651 -0.0109 0.0392 0.0294 -2.4580e-04 0.0053 -0.0109 -0.0263 0.0124 0.0510 0.0552 0.0334 0.0030 0.0360 -0.0175 0.0352 1.0632 -0.0558 0.0297 -0.0022 0.0471 0.0608 -0.0321 -0.0632 0.0323 -0.0454 -1.2554 1.5378e-04 -0.0936 -0.0463 -0.0355 -0.2206 -1.8689 -0.2118 1.4526 -1.0563 0.5408 -0.0652 -0.0580 -0.0192 -0.0064 0.0452 -0.0358 -0.0312 -0.0435 -0.0383 -0.0761 0.0243 -0.0194 -0.0318 0.0490 0.0493 -0.0071 -0.0176 0.0352 -0.0531 -0.0099 0.0460 0.0375 0.0377 -0.0687 0.0032 0.0478 0.0475 0.0151 -0.0557 0.0310 0.0059 0.0285 0.0359 0.0034 0.0707 -0.0090 -0.0561 0.0017 0.0465 -0.0246 0.0017]}    {1x1 struct}    0.29821

% %%
fig=findobj(0,'tag','pl_augstar');
figure(fig(1))

if prin==1
    % print to postscript
    print -depsc glyph1.eps;
else
    sgtitle('Figure 7.10')
    set(gcf,"Name",'Figure 7.10')
end
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_1.png"></center>

% %% [markdown]
% ## Create Figure 7.11: all options set to false,

% %%
outNoOption=avas(y,X,'rob',false,'tyinitial',false,...
    'scail',false,'orderR2',false,'trapezoid',false);
aceplot(outNoOption,'oneplot',true)

disp('pvalue of DW test (no option is used)')
% Out:
% pvalue of DW test (no option is used)

% %%
disp(outNoOption.pvaldw)
% Out:
% 1.6380e-08

% %%
disp('Value of R2 (no option is used)')
% Out:
% Value of R2 (no option is used)

% %%
disp(outNoOption.rsq)
% Out:
%     0.8440

% %%
if prin==1
    % print to postscript
    print -depsc glyph1bis.eps;
else
    sgtitle('Figure 7.11')
    set(gcf,"Name",'Figure 7.11')
end
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_2.png"></center>

% %% [markdown]
% ## Create Figure 7.12: all options set to true

% %%
outALlopt=avas(y,X,'rob',true,'tyinitial',true,...
    'scail',true,'orderR2',true,'trapezoid',true);
aceplot(outALlopt,'oneplot','')
disp(outALlopt)
% Out:
%            y: [151x1 double]
%           ty: [151x1 double]
%            X: [151x4 double]
%           tX: [151x4 double]
%          rsq: 0.9984
%        niter: 3
%     outliers: [53 90 100 105 106 107 108 109 110]
%       pvaldw: 0.6104
%       pvaljb: 0.0899

% %%
disp(['Number of outliers generated using all options=' num2str(length(outALlopt.outliers))])
% Out:
% Number of outliers generated using all options=9

% %%
if prin==1
    % print to postscript
    print -depsc figs\glyph1tris.eps;
else
    sgtitle('Figure 7.12')
    set(gcf,"Name",'Figure 7.12')
end
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_3.png"></center>

% %%
%InsideREADME
